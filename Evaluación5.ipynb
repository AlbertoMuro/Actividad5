# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from funpymodeling.exploratory import freq_tbl

# %%
df=pd.read_excel("microretailer_mit_lift_lab.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Columns: 106 entries, _record_id to 235_email
# dtypes: float64(23), int64(2), object(81)
# memory usage: 141.7+ KB

# %% [markdown]
# **Seleccionamos las variables de nuestro interés.**

# %%
data=df.iloc[ : , [9,11,12,16,21,22,23,24,25,26,27,30,31,34,35,36,47,52,53,79,82,88] ] #Columnas no consecutivas
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 22 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   232_type_of_store                                      171 non-null    object
#  1   99_does_the_micro_retailer_exhibits_products_outside_  171 non-null    object
#  2   102_does_the_micro_retailer_sells_fresh_products_      171 non-null    object
#  3   104_how_many_shelves_does_the_micro_retailer_have      171 non-null    int64
#  4   2_current_permanent_employees                          111 non-null    float64
#  5   4_number_permanent_employees_last_year                 95 non-null     float64
#  6   5_change_store_space_last_year                         99 non-null     object
#  7   6_change_employees_average_salary_last_year            85 non-null     object
# ...

# %%
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("No cambió",0)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Disminuyó 15%",-15)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Disminuyó 25%",-25)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Disminuyó 50% o más",-50)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Aumentó 15%",15)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Aumentó 25%",25)
data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Aumentó 50% o más",50)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("No cambió",0)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Disminuyó 15%",-15)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Disminuyó 25%",-25)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Disminuyó 50% o más",-50)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Aumentó 15%",15)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Aumentó 25%",25)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Aumentó 50% o más",50)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("Dependiente ",0)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("No hay empleándosela ",0)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("0",0)
data["6_change_employees_average_salary_last_year"]=data["6_change_employees_average_salary_last_year"].replace("40",0)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("50% +",50)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("5%",5)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("10%",10)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("15%",15)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("20%",20)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("25%",25)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("30%",30)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("35%",35)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("40%",40)
data["38_average_margin_profits"]=data["38_average_margin_profits"].replace("45%",45)
# Out:
# C:\Users\Carlos Casillas\AppData\Local\Temp\ipykernel_35836\3157339352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("No cambió",0)
# C:\Users\Carlos Casillas\AppData\Local\Temp\ipykernel_35836\3157339352.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["5_change_store_space_last_year"]=data["5_change_store_space_last_year"].replace("Disminuyó 15%",-15)
# ...

# %%
freq_tbl(data)
# Out:
#                   232_type_of_store  frequency  percentage  cumulative_perc
# 0    Grocery store (aka. nanostore)         52    0.304094         0.304094
# 1   Micro-restaurant (aka. fondita)         31    0.181287         0.485380
# 2                    Dairy products         10    0.058480         0.543860
# 3                         Cafeteria          6    0.035088         0.578947
# 4                      Butcher shop          6    0.035088         0.614035
# ..                              ...        ...         ...              ...
# 59                          joyeria          1    0.005848         0.976608
# 60                         dulceria          1    0.005848         0.982456
# 61                             Ropa          1    0.005848         0.988304
# 62                       Ferretería          1    0.005848         0.994152
# 63         productos tradicionales           1    0.005848         1.000000
#
# [64 rows x 4 columns]
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 22 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   232_type_of_store                                      171 non-null    object
#  1   99_does_the_micro_retailer_exhibits_products_outside_  171 non-null    object
#  2   102_does_the_micro_retailer_sells_fresh_products_      171 non-null    object
#  3   104_how_many_shelves_does_the_micro_retailer_have      171 non-null    int64
#  4   2_current_permanent_employees                          111 non-null    float64
#  5   4_number_permanent_employees_last_year                 95 non-null     float64
#  6   5_change_store_space_last_year                         99 non-null     float64
#  7   6_change_employees_average_salary_last_year            85 non-null     float64
# ...

# %%
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# 232_type_of_store                                          0
# 99_does_the_micro_retailer_exhibits_products_outside_      0
# 102_does_the_micro_retailer_sells_fresh_products_          0
# 104_how_many_shelves_does_the_micro_retailer_have          0
# 2_current_permanent_employees                             60
# 4_number_permanent_employees_last_year                    76
# 5_change_store_space_last_year                            72
# 6_change_employees_average_salary_last_year               86
# 20_reviews_finances_monthly                               63
# 49_inventory_records                                      61
# 18_sales_records                                          61
# 19_tax_id                                                 71
# 145_number_direct_competitors                             68
# 186_internet_connection                                   63
# 210_sales_channels                                        89
# ...

# %% [markdown]
# Hacemos el primer código, en este comparamos a los establecimientos en base a el % de utilidad y el tipo de venta

# %%
filtro1=data.iloc[ : , [0,17] ] #Columnas no consecutivas
filtro1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   232_type_of_store          171 non-null    object
#  1   38_average_margin_profits  66 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 2.8+ KB

# %%
tienda_utilidad=filtro1[(filtro1["38_average_margin_profits"]>=30)]
tienda_utilidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 11 to 165
# Data columns (total 2 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   232_type_of_store          32 non-null     object
#  1   38_average_margin_profits  32 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 768.0+ bytes

# %%
table1=freq_tbl(tienda_utilidad["232_type_of_store"])
table1
# Out:
#                    232_type_of_store  frequency  percentage  cumulative_perc
# 0    Micro-restaurant (aka. fondita)          8     0.25000          0.25000
# 1     Grocery store (aka. nanostore)          5     0.15625          0.40625
# 2                          Cafeteria          4     0.12500          0.53125
# 3                          internet           1     0.03125          0.56250
# 4                 Tailor (sastrería)          1     0.03125          0.59375
# 5                        tecnología           1     0.03125          0.62500
# 6                        lavandería           1     0.03125          0.65625
# 7                        ferretería           1     0.03125          0.68750
# 8                           Floreria          1     0.03125          0.71875
# 9                          Papelería          1     0.03125          0.75000
# 10                              Ropa          1     0.03125          0.78125
# ...

# %%
Filtro_index=table1.set_index("232_type_of_store")
Filtro_index
# Out:
#                                   frequency  percentage  cumulative_perc
# 232_type_of_store
# Micro-restaurant (aka. fondita)           8     0.25000          0.25000
# Grocery store (aka. nanostore)            5     0.15625          0.40625
# Cafeteria                                 4     0.12500          0.53125
# internet                                  1     0.03125          0.56250
# Tailor (sastrería)                        1     0.03125          0.59375
# tecnología                                1     0.03125          0.62500
# lavandería                                1     0.03125          0.65625
# ferretería                                1     0.03125          0.68750
# Floreria                                  1     0.03125          0.71875
# Papelería                                 1     0.03125          0.75000
# Ropa                                      1     0.03125          0.78125
# Pet store                                 1     0.03125          0.81250
# ...

# %%
#Grafico de barras
Filtro_index.plot(kind="bar",width=1,figsize=(10,4))
plt.title("Ganancias superiores al 30% ")
plt.xlabel("Tipo de establecimiento")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Gráficas crecimiento en salario de los empleados con herramientas ERP

# %%
filtro2=data.iloc[ : , [8,9,10,11,17,18,19,20,6] ] #Columnas no consecutivas
filtro2.head()
# Out:
#   20_reviews_finances_monthly                  49_inventory_records  \
# 0                         yes  Software especializado + computadora
# 1                         yes                            No lo hago
# 2                         yes                              En Excel
# 3                         yes  Software especializado + computadora
# 4                         yes                              En papel
#
#                        18_sales_records 19_tax_id  38_average_margin_profits  \
# 0  Software especializado + computadora       yes                        NaN
# 1                            No lo hago        no                        NaN
# 2  Software especializado + computadora        no                        NaN
# 3  Software especializado + computadora       yes                        NaN
# 4                              En papel       yes                        NaN
#
#   193_sales_planning_tools 185_place_orders_suppliers  \
# ...

# %%
margen_erp=filtro2[(filtro2["20_reviews_finances_monthly"]=="yes")&(filtro2["193_sales_planning_tools"]!="Ninguna")&(filtro2["38_average_margin_profits"]>=30)]
margen_erp.head(25)
# Out:
#     20_reviews_finances_monthly  \
# 11                          yes
# 16                          yes
# 36                          yes
# 40                          yes
# 48                          yes
# 51                          yes
# 53                          yes
# 60                          yes
# 63                          yes
# 67                          yes
# 70                          yes
# 77                          yes
# 83                          yes
# 123                         yes
# 154                         yes
# 156                         yes
# 160                         yes
# 161                         yes
# 162                         yes
# 165                         yes
#
#                                   49_inventory_records  \
# 11                Software especializado + computadora
# 16                                            En Excel
# 36                                            En papel
# ...

# %%
table2=freq_tbl(margen_erp["193_sales_planning_tools"])
table2
# Out:
#                   193_sales_planning_tools  frequency  percentage  \
# 0                                 Cuaderno          8        0.40
# 1                                    Excel          3        0.15
# 2                   Software especializado          2        0.10
# 3                           Cuaderno,Excel          2        0.10
# 4  Aplicación móvil,Software especializado          1        0.05
# 5             Excel,Software especializado          1        0.05
# 6                               En físico           1        0.05
# 7                   Aplicación móvil,Excel          1        0.05
#
#    cumulative_perc
# 0         0.421053
# 1         0.578947
# 2         0.684211
# 3         0.789474
# 4         0.842105
# 5         0.894737
# 6         0.947368
# 7         1.000000

# %%
filtro_table2=table2[table2["frequency"]>1]
filtro_table2
# Out:
#   193_sales_planning_tools  frequency  percentage  cumulative_perc
# 0                 Cuaderno          8        0.40         0.421053
# 1                    Excel          3        0.15         0.578947
# 2   Software especializado          2        0.10         0.684211
# 3           Cuaderno,Excel          2        0.10         0.789474

# %%
filtro_index2=filtro_table2.set_index("193_sales_planning_tools")
filtro_index2
# Out:
#                           frequency  percentage  cumulative_perc
# 193_sales_planning_tools
# Cuaderno                          8        0.40         0.421053
# Excel                             3        0.15         0.578947
# Software especializado            2        0.10         0.684211
# Cuaderno,Excel                    2        0.10         0.789474

# %%
filtro_index2.plot(kind="bar",width=1,figsize=(10,4))
plt.title("Herramientas utilizadas para el análisis de venta")
plt.xlabel("Tipo de herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Grafica de herramientas para inventario**

# %%
margen_erp2=filtro2[(filtro2["20_reviews_finances_monthly"]=="yes")&(filtro2["49_inventory_records"]!="Ninguna")&(filtro2["38_average_margin_profits"]>=30)]
margen_erp2.head(25)
# Out:
#     20_reviews_finances_monthly                  49_inventory_records  \
# 11                          yes  Software especializado + computadora
# 16                          yes                              En Excel
# 34                          yes                              En papel
# 36                          yes                              En papel
# 37                          yes                              En Excel
# 40                          yes                              En papel
# 48                          yes                              En papel
# 51                          yes                              En papel
# 53                          yes                              En Excel
# 60                          yes                              En Excel
# 63                          yes                              En Excel
# 65                          yes                              En papel
# ...

# %%
table3=freq_tbl(margen_erp2["49_inventory_records"])
table3
# Out:
#                                 49_inventory_records  frequency  percentage  \
# 0                                           En papel         14    0.500000
# 1                                           En Excel          7    0.250000
# 2                                  En Excel,En papel          3    0.107143
# 3               Software especializado + computadora          2    0.071429
# 4                                    En papel,Mental          1    0.035714
# 5  Aplicación móvil (i.e. App) + smartphone,En Excel          1    0.035714
#
#    cumulative_perc
# 0         0.500000
# 1         0.750000
# 2         0.857143
# 3         0.928571
# 4         0.964286
# 5         1.000000

# %%
filtro_index3=table3.set_index("49_inventory_records")
filtro_index3
# Out:
#                                                    frequency  percentage  \
# 49_inventory_records
# En papel                                                  14    0.500000
# En Excel                                                   7    0.250000
# En Excel,En papel                                          3    0.107143
# Software especializado + computadora                       2    0.071429
# En papel,Mental                                            1    0.035714
# Aplicación móvil (i.e. App) + smartphone,En Excel          1    0.035714
#
#                                                    cumulative_perc
# 49_inventory_records
# En papel                                                  0.500000
# En Excel                                                  0.750000
# En Excel,En papel                                         0.857143
# Software especializado + computadora                      0.928571
# En papel,Mental                                           0.964286
# ...

# %%
filtro_index3.plot(kind="bar",width=1,figsize=(10,4))
plt.title("Herramientas utilizadas para el análisis de inventario")
plt.xlabel("Tipo de herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Herramientas para proveedores**

# %%
margen_erp3=filtro2[(filtro2["20_reviews_finances_monthly"]=="yes")&(filtro2["185_place_orders_suppliers"]!="Ninguna")&(filtro2["38_average_margin_profits"]>=30)]
margen_erp3.head(25)
# Out:
#     20_reviews_finances_monthly                  49_inventory_records  \
# 11                          yes  Software especializado + computadora
# 16                          yes                              En Excel
# 34                          yes                              En papel
# 36                          yes                              En papel
# 37                          yes                              En Excel
# 40                          yes                              En papel
# 48                          yes                              En papel
# 51                          yes                              En papel
# 53                          yes                              En Excel
# 60                          yes                              En Excel
# 63                          yes                              En Excel
# 65                          yes                              En papel
# ...

# %%
table4=freq_tbl(margen_erp3["185_place_orders_suppliers"])
table4
# Out:
#                            185_place_orders_suppliers  frequency  percentage  \
# 0                                          En persona          5    0.178571
# 1              Mensajería instantánea (e.g. WhatsApp)          4    0.142857
# 2                       En persona,Llamada telefónica          3    0.107143
# 3   En persona,Llamada telefónica,Mensajería insta...          3    0.107143
# 4   En persona,Mensajería instantánea (e.g. WhatsApp)          3    0.107143
# 5                                  Llamada telefónica          2    0.071429
# 6                              Mensaje de texto (SMS)          2    0.071429
# 7   Mensaje de texto (SMS),Mensajería instantánea ...          2    0.071429
# 8                            Página web del proveedor          1    0.035714
# 9        Email,Mensajería instantánea (e.g. WhatsApp)          1    0.035714
# 10                                   Email,En persona          1    0.035714
#
#     cumulative_perc
# 0          0.185185
# ...

# %%
filtro_index4=table4.set_index("185_place_orders_suppliers")
filtro_index4
# Out:
#                                                     frequency  percentage  \
# 185_place_orders_suppliers
# En persona                                                  5    0.178571
# Mensajería instantánea (e.g. WhatsApp)                      4    0.142857
# En persona,Llamada telefónica                               3    0.107143
# En persona,Llamada telefónica,Mensajería instan...          3    0.107143
# En persona,Mensajería instantánea (e.g. WhatsApp)           3    0.107143
# Llamada telefónica                                          2    0.071429
# Mensaje de texto (SMS)                                      2    0.071429
# Mensaje de texto (SMS),Mensajería instantánea (...          2    0.071429
# Página web del proveedor                                    1    0.035714
# Email,Mensajería instantánea (e.g. WhatsApp)                1    0.035714
# Email,En persona                                            1    0.035714
#
# ...

# %%
filtro_index4.plot(kind="bar",width=1,figsize=(10,4))
plt.title("Herramientas utilizadas para el contacto con proveedores")
plt.xlabel("Tipo de herramienta")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# **Relación con los clientes**

# %%
margen_clientes=data.iloc[ : , [14,15,16,21,17] ] #Columnas no consecutivas
margen_clientes.head()
# Out:
#                                   210_sales_channels  \
# 0  Llamada a Teléfono celular,Llamada a Teléfono ...
# 1                                           WhatsApp
# 2  Redes sociales (e.g. Facebook, Instagram),What...
# 3                            Llamada a Teléfono fijo
# 4                         Llamada a Teléfono celular
#
#                                  189_payment_methods  \
# 0               Efectivo,Transferencia interbancaria
# 1               Efectivo,Transferencia interbancaria
# 2             Efectivo,Tarjeta de débito y/o crédito
# 3  Efectivo,Tarjeta de débito y/o crédito,Transfe...
# 4  Efectivo,Tarjeta de débito y/o crédito,Transfe...
#
#   214_customer_relationship_tools  \
# 0                  Redes sociales
# 1                Aplicación móvil
# 2                  Redes sociales
# 3                        Teléfono
# 4                             NaN
#
#                                161_actions_stockouts  \
# ...

# %%
margen_clientes2=margen_clientes[(margen_clientes["210_sales_channels"]!="Ninguno")&(filtro2["38_average_margin_profits"]>=30)]
margen_clientes2.head(25)
# Out:
#                                     210_sales_channels  \
# 11   Llamada a Teléfono celular,Redes sociales (e.g...
# 16           Redes sociales (e.g. Facebook, Instagram)
# 17                 Llamada a Teléfono celular,WhatsApp
# 34   Redes sociales (e.g. Facebook, Instagram),What...
# 36                             Llamada a Teléfono fijo
# 37                                            Volantes
# 40                                                 NaN
# 48   Aplicación móvil (e.g. Rappi, Uber Eats),Llama...
# 51                                            WhatsApp
# 53           Redes sociales (e.g. Facebook, Instagram)
# 60   Redes sociales (e.g. Facebook, Instagram),What...
# 63                                            WhatsApp
# 65                                                  no
# 67                                   Página web propia
# 69            Aplicación móvil (e.g. Rappi, Uber Eats)
# 70            Aplicación móvil (e.g. Rappi, Uber Eats)
# ...

# %%
table5=freq_tbl(margen_clientes2["210_sales_channels"])
table5
# Out:
#                                    210_sales_channels  frequency  percentage  \
# 0           Redes sociales (e.g. Facebook, Instagram)          5     0.15625
# 1                                            WhatsApp          4     0.12500
# 2                 Llamada a Teléfono celular,WhatsApp          3     0.09375
# 3   Redes sociales (e.g. Facebook, Instagram),What...          3     0.09375
# 4   Llamada a Teléfono celular,Redes sociales (e.g...          2     0.06250
# 5            Aplicación móvil (e.g. Rappi, Uber Eats)          2     0.06250
# 6                             Llamada a Teléfono fijo          1     0.03125
# 7                                            Volantes          1     0.03125
# 8   Aplicación móvil (e.g. Rappi, Uber Eats),Llama...          1     0.03125
# 9                                                  no          1     0.03125
# 10                                  Página web propia          1     0.03125
# ...

# %%
table6=table5[table5["frequency"]>1]
table6
# Out:
#                                   210_sales_channels  frequency  percentage  \
# 0          Redes sociales (e.g. Facebook, Instagram)          5     0.15625
# 1                                           WhatsApp          4     0.12500
# 2                Llamada a Teléfono celular,WhatsApp          3     0.09375
# 3  Redes sociales (e.g. Facebook, Instagram),What...          3     0.09375
# 4  Llamada a Teléfono celular,Redes sociales (e.g...          2     0.06250
# 5           Aplicación móvil (e.g. Rappi, Uber Eats)          2     0.06250
#
#    cumulative_perc
# 0         0.172414
# 1         0.310345
# 2         0.413793
# 3         0.517241
# 4         0.586207
# 5         0.655172

# %%
table6=table6.set_index("210_sales_channels")
table6
# Out:
#                                                     frequency  percentage  \
# 210_sales_channels
# Redes sociales (e.g. Facebook, Instagram)                   5     0.15625
# WhatsApp                                                    4     0.12500
# Llamada a Teléfono celular,WhatsApp                         3     0.09375
# Redes sociales (e.g. Facebook, Instagram),WhatsApp          3     0.09375
# Llamada a Teléfono celular,Redes sociales (e.g....          2     0.06250
# Aplicación móvil (e.g. Rappi, Uber Eats)                    2     0.06250
#
#                                                     cumulative_perc
# 210_sales_channels
# Redes sociales (e.g. Facebook, Instagram)                  0.172414
# WhatsApp                                                   0.310345
# Llamada a Teléfono celular,WhatsApp                        0.413793
# Redes sociales (e.g. Facebook, Instagram),WhatsApp         0.517241
# Llamada a Teléfono celular,Redes sociales (e.g....         0.586207
# ...

# %%
table6.plot(kind="bar",width=1,figsize=(10,4))
plt.title("Canales de venta para clientes")
plt.xlabel("Canales registrados")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Metodos de pago

# %%
margen_clientes3=margen_clientes[(margen_clientes["189_payment_methods"]!="Ninguno")&(margen_clientes["38_average_margin_profits"]>40)]
margen_clientes2.head(25)
# Out:
#                                     210_sales_channels  \
# 11   Llamada a Teléfono celular,Redes sociales (e.g...
# 16           Redes sociales (e.g. Facebook, Instagram)
# 17                 Llamada a Teléfono celular,WhatsApp
# 34   Redes sociales (e.g. Facebook, Instagram),What...
# 36                             Llamada a Teléfono fijo
# 37                                            Volantes
# 40                                                 NaN
# 48   Aplicación móvil (e.g. Rappi, Uber Eats),Llama...
# 51                                            WhatsApp
# 53           Redes sociales (e.g. Facebook, Instagram)
# 60   Redes sociales (e.g. Facebook, Instagram),What...
# 63                                            WhatsApp
# 65                                                  no
# 67                                   Página web propia
# 69            Aplicación móvil (e.g. Rappi, Uber Eats)
# 70            Aplicación móvil (e.g. Rappi, Uber Eats)
# ...
